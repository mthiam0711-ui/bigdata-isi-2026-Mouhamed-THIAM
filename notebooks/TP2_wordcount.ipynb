# %% [markdown]
# # TP 2 — Premiers pas PySpark
#
# **Big Data Engineering — Master 1 — DMI/FST/UCAD — Prof. Samba Ndiaye**
#
# Ce notebook guide les parties B (WordCount), C (fil rouge) et D (Spark UI)
# du TP 2. Complétez les cellules marquées `À COMPLÉTER`, exécutez tout de bout
# en bout, puis poussez le notebook **avec ses sorties** dans `notebooks/`.
#
# **Livrable** : ce notebook, avec le WordCount **commenté ligne à ligne**, les
# observations de la Spark UI, et la comparaison Spark vs Pandas.
#
# > Réflexe d'ingénieur : on ne dit pas « c'est lent », on dit « 4,2 s pour
# > 50 000 lignes ». Mesurez tout.

# %% [markdown]
# ## 0. Vérification de l'environnement
#
# PySpark s'exécute sur la JVM : un **JDK 17** est requis. Si la cellule
# échoue, revenez à la partie A du TP (`java -version`).

# %%
import sys, platform
import pyspark
print("Python  :", sys.version.split()[0], "-", platform.system())
print("PySpark :", pyspark.__version__)
# Out:
# Python  : 3.12.12 - Darwin
# PySpark : 3.5.1

# %% [markdown]
# ## 1. Créer la SparkSession
#
# `master("local[*]")` exécute Spark dans ce notebook, sur **tous les cœurs**
# de la machine. La Spark UI démarre sur http://localhost:4040 — ouvrez-la.

# %%
from pyspark.sql import SparkSession

spark = (SparkSession.builder
         .appName("TP2-WordCount")
         .master("local[*]")
         .getOrCreate())

print("Spark", spark.version)
print("Coeurs vus :", spark.sparkContext.defaultParallelism)
print("Spark UI   :", spark.sparkContext.uiWebUrl)
# Out:
# Spark 3.5.1
# Coeurs vus : 4
# Spark UI   : http://air-de-mac.home:4042

# %% [markdown]
# ## Exercice B — WordCount
#
# Préparez d'abord un fichier texte dans `data/discours.txt` (un discours, un
# article — au moins quelques centaines de mots). La cellule ci-dessous compte
# les mots. **Commentez chaque ligne** : c'est le cœur du livrable.

# %%
import os
print(os.getcwd())
print(os.listdir("."))
# Out:
# /Users/mac/Desktop/dsia/bigdata/venv-bigdata-312
# ['TP2_wordcount.ipynb', '.DS_Store', 'bin', 'include', 'etc', 'pyvenv.cfg', 'lib', '.ipynb_checkpoints', 'share']

# %%
import os
os.makedirs("data", exist_ok=True)

texte = """Il était une fois une princesse qui vivait dans un grand château.
La princesse aimait se promener dans le jardin du château.
Chaque matin la princesse saluait les oiseaux et les fleurs.
Un jour la princesse rencontra un dragon près de la rivière.
Le dragon n'était pas méchant et la princesse devint son amie.
Ensemble la princesse et le dragon explorèrent la forêt.
La princesse était courageuse et le dragon était fidèle.
Le roi et la reine étaient fiers de leur princesse.
Le château brillait sous le soleil et la princesse souriait.
Ainsi la princesse vécut heureuse avec le dragon pour toujours."""

with open("data/discours.txt", "w", encoding="utf-8") as f:
    f.write(texte)

print("Fichier créé.")
# Out:
# Fichier créé.

# %%
# === À COMPLÉTER ===
from pyspark.sql.functions import explode, split, lower, col

texte = spark.read.text("data/discours.txt")

mots = (texte
        # ... que fait split(lower(col("value")), r"\s+") ?
        .select(explode(split(lower(col("value")), r"\s+")).alias("mot"))
        .filter(col("mot") != "")
        # ... pourquoi groupBy provoque-t-il un shuffle ?
        .groupBy("mot")
        .count())

mots.orderBy(col("count").desc()).show(15)
# Out:
# +----------+-----+
# |       mot|count|
# +----------+-----+
# |        la|   11|
# | princesse|    9|
# |        le|    8|
# |        et|    6|
# |    dragon|    5|
# |     était|    3|
# |        un|    3|
# |       les|    2|
# |        de|    2|
# |  château.|    2|
# |      dans|    2|
# |       une|    2|
# |   fleurs.|    1|
# |        du|    1|
# |courageuse|    1|
# +----------+-----+
# only showing top 15 rows

# %% [raw]
# # split(lower(col("value")), r"\s+") :
# #   lower -> tout en minuscules (la = La)
# #   split sur \s+ -> découpe chaque ligne en liste de mots sur les espaces
# #   ex : "La princesse dort" -> ["la", "princesse", "dort"]
#
# # groupBy provoque un shuffle car pour compter par mot, Spark doit
# # rassembler toutes les occurrences d'un même mot sur la même partition.
# # Ces mots sont éparpillés sur plusieurs partitions au départ -> redistribution
# # réseau (le shuffle), l'opération la plus coûteuse de Spark.

# %% [markdown]
# ### B — Observer (répondez en markdown)
#
# 1. Quelles lignes sont des **transformations** ? Laquelle est l'**action** ?
# 2. Où se situe le **shuffle** ?
# 3. Si vous relancez `mots.orderBy(...).show()`, pourquoi tout est-il
#    recalculé ?
#
# *Vos réponses :* …

# %% [raw]
# ## B — Observer
#
# ### 1. Transformations vs action
#
# **Transformations** (lazy, ne déclenchent aucun calcul, construisent juste le plan) :
# - `spark.read.text("data/discours.txt")` — crée le DataFrame (lazy)
# - `.select(explode(split(lower(col("value")), r"\s+")).alias("mot"))`
# - `.filter(col("mot") != "")`
# - `.groupBy("mot").count()`
# - `.orderBy(col("count").desc())`
#
# **Action** (déclenche l'exécution réelle du plan) :
# - `.show(15)`
#
# Tant qu'on n'appelle pas `show()`, Spark n'a rien calculé : il n'a fait que empiler les transformations dans un plan logique. C'est l'**évaluation paresseuse** (lazy evaluation).
#
# ### 2. Où se situe le shuffle ?
#
# Au niveau du **`groupBy("mot")`**. Pour regrouper les occurrences d'un même mot, Spark doit redistribuer les données à travers les partitions (envoyer chaque mot vers la partition qui lui correspond, par hash). C'est un premier shuffle.
#
# Le **`orderBy(col("count").desc())`** provoque, lui aussi, un shuffle : le tri global impose de redistribuer les données pour les ordonner sur toutes les partitions.
#
# Il y a donc **deux shuffles** dans ce pipeline : un au `groupBy`, un au `orderBy`.
#
# ### 3. Pourquoi tout est recalculé si on relance `show()` ?
#
# Parce que Spark **ne conserve pas les résultats intermédiaires en mémoire par défaut**. Un DataFrame ne stocke pas de données : il ne mémorise que le **plan de calcul** (la suite des transformations depuis la lecture du fichier).
#
# À chaque action (`show()`), Spark **réexécute tout le plan depuis le début** : relecture du fichier, split, explode, filter, groupBy, orderBy. Rien n'est réutilisé d'une exécution à l'autre.
#
# Pour éviter ce recalcul, il faudrait matérialiser le résultat en mémoire avec `.cache()` ou `.persist()` : Spark garderait alors les données calculées et les réutiliserait aux appels suivants.

# %% [markdown]
# ## Exercice C — Recharger le fil rouge avec Spark
#
# On reprend les fichiers du fil rouge, cette fois avec Spark. `inferSchema`
# demande à Spark de **deviner** les types (pratique mais coûteux : une passe
# de lecture en plus).

# %%
# === À COMPLÉTER ===
orders = (spark.read
          .option("header", True)
          .option("inferSchema", True)
          .csv("data/orders.csv"))

events = spark.read.json("data/events.json")   # JSON Lines

orders.printSchema()
print("orders :", orders.count())    # nombre de lignes
events.printSchema()

# %% [markdown]
# ### C — Explorer sans tout rapatrier
#
# `show(n)` et `count()` sont des actions ; `select`, `filter`, `groupBy`
# décrivent seulement le plan. **Ne jamais** faire `events.collect()`.

# %%
# === À COMPLÉTER ===
orders.select("order_id", "statut", "canal").show(5)

livrees = orders.filter(col("statut") == "livree")
print("livrees :", ...)

orders.groupBy("statut").count().show()
# ... compter par canal, trie par count decroissant
...

# %% [markdown]
# ## Exercice C.3 — Spark vs Pandas : mesurez
#
# Chronométrez Spark sur `orders.csv`, comparez à votre mesure Pandas du TP 1
# (même fichier, échelle 0.1). Lequel gagne sur ce petit volume ?

# %%
# === À COMPLÉTER ===
import time

t0 = time.perf_counter()
n = spark.read.option("header", True).csv("data/orders.csv").count()
t_spark = time.perf_counter() - t0
print("Spark : %.2f s pour %d lignes" % (t_spark, n))

# Reportez ici votre temps Pandas du TP 1 :
t_pandas = ...
print("Pandas (TP1) : %s s" % t_pandas)

# %% [markdown]
# ## Exercice D — Lire la Spark UI
#
# Ouvrez http://localhost:4040. Cette cellule donne les partitions ; le reste
# s'observe **dans le navigateur** (onglets Jobs, Stages, SQL/DataFrame).

# %%
# === À COMPLÉTER ===
print("Partitions orders :", orders.rdd.getNumPartitions())
print("Coeurs disponibles :", spark.sparkContext.defaultParallelism)

# Relancez le WordCount pour le retrouver dans l'onglet Jobs :
mots.orderBy(col("count").desc()).show(5)

# %% [markdown]
# ### D — Relevés (complétez en markdown)
#
# - Nombre de stages du WordCount : …
# - Shuffle Read / Write du stage d'agrégation : …
# - Nombre de tasks par stage / nombre de partitions : …
# - Tasks en parallèle vs nombre de cœurs : …

# %% [markdown]
# ## 5. Avant de pousser
#
# Vérifiez : WordCount commenté ligne à ligne, observations Spark UI
# renseignées, comparaison Spark/Pandas chiffrée. Puis :
#
# ```bash
# git add notebooks/TP2_wordcount.ipynb
# git commit -m "TP2 : WordCount PySpark, fil rouge, Spark UI"
# git push
# ```
#
# Pensez à **arrêter la session** en fin de travail : `spark.stop()`.

# %%
spark.stop()
